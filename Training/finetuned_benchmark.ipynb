# %% [markdown]
# <a href="https://colab.research.google.com/github/giyushino/MyOwnDoodleGuesser/blob/main/fine_tuned_larger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install torch
# !pip install datasets
from transformers import CLIPProcessor, CLIPModel
import torch
import time
import random
import numpy as np
from PIL import Image
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)

# %%
model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-large-patch14")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %%
dataset2 = []
files = ["full_numpy_bitmap_crab.npy", "full_numpy_bitmap_crocodile.npy", "full_numpy_bitmap_lion.npy",
         "full_numpy_bitmap_lobster.npy", "full_numpy_bitmap_monkey.npy", "full_numpy_bitmap_octopus.npy",
         "full_numpy_bitmap_panda.npy", "full_numpy_bitmap_swan.npy"]


# For each class, we are giving them a corresponding label: 0 to 5
class_labels = {
    "full_numpy_bitmap_crab.npy": 0,
    "full_numpy_bitmap_crocodile.npy": 1,
    "full_numpy_bitmap_lion.npy": 2,
    "full_numpy_bitmap_lobster.npy": 3,
    "full_numpy_bitmap_monkey.npy": 4,
    "full_numpy_bitmap_octopus.npy": 5,
    "full_numpy_bitmap_panda.npy": 6,
    "full_numpy_bitmap_swan.npy": 7
}

for filename in files:
    images = np.load(filename)
    print(f"Loaded {filename} with shape: {images.shape}")

    t_0 = time.perf_counter()
    count = 0

    # Loop through each image in the file
    for i in range(len(images)):
        # Only process the first 1000 images from each class

        image = images[i]  # Provides (728,) array
        reshape = image.reshape(28, 28)  # Reshapes to (28, 28) numpy array
        image = Image.fromarray(reshape)
        grayscale_image = image.convert("RGB")

        # Assign the label based on the class of the file
        label = class_labels[filename]  # Get the label for the class

        data = {
            'image': grayscale_image,  # The image tensor
            'label': label  # The corresponding label (class)
        }

        dataset2.append(data)
        count += 1

    t_1 = time.perf_counter()
    print(f"Successfully processed {filename} in {t_1 - t_0:.2f} seconds")



labels = ["a drawing of a crab", "a drawing of a crocodile", "a drawing of a lion", "a drawing of a lobster",
          "a drawing of a monkey", "a drawing of a octopus", "a drawing of a panda", "a drawing of a swan"]
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label

print(label2id)


random.shuffle(dataset2)

def homemade_batch(num_img, batch_size=10, start_img=0, data_type = "test"):
    # Initialize empty set to store predicted values and their probabilities
    homemade = []
    num_batches = num_img // batch_size
    extra = num_img % batch_size # Not implemented yet

    # Allows computations to be run on GPU instead of CPU
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    t_0 = time.perf_counter()

    for i in range(num_batches):
        t1 = time.perf_counter()

        # Create a temporary batch of data
        start = i * batch_size + start_img
        end = (i + 1) * batch_size + start_img

        batch = dataset2[start:end]
        images = [item["image"] for item in batch]


        subset = dataset2[start:end]
        input = processor(text=labels, images=images, return_tensors="pt", padding=False).to(device)
        output = model(**input)

        # Access logits of the input images, apply softmax function
        logits = output.logits_per_image
        probs = logits.softmax(dim=1)

        # Find maximum of the probabilities, as well as their corresponding index, append them to list
        max_prob, max_id = probs.max(dim=1)
        homemade.append([max_prob.cpu().detach(), max_id.cpu().detach()])
        torch.cuda.empty_cache()

        if i % 50 == 0:
          t2 = time.perf_counter()
          print(f"Finished batch {i + 1} of {num_batches} in {t2 - t1} seconds")

    t_3 = time.perf_counter()
    print(f"Finished entire dataset in {t_3 - t_0} seconds")

    # Returns list of tensors, structure is [[tensor([first batch maximum probabilities]), tensor([corresponding indices/labels])],
    #                                         [tensor([second batch maximum probabilities]), tensor([corresponding indices/labels])],
    #                                         [tensor([third batch maximum probabilities]), tensor([corresponding indices/labels])]]
    return homemade


# Takes output of homemade_batch as input and returns clean data
def prediction_reformat(subset):
    # Initialize empty list to store new reformatted data
    predicted = []
    count = 0

    # len(subset) = number of batches
    for i in range(len(subset)):
        for k in range(len(subset[0][0])):
            prob = subset[i][0][k].item()
            id = subset[i][1][k].item()

            label = id2label[id]
            predicted.append([count, label, prob, id])

            count += 1

    # Returns nested list with form [[index, "label", probability, id],
    #                                [index, "label", probability, id]]
    return predicted

def accuracy(result, data_type = "test"):
    correct = 0
    total = 0

    # Create dictionary to count how many of each label occurs in the subset, all labels initialized to 0
    all_labels = {}
    for label in labels:
        all_labels[label] = 0

    # Dictionary to keep track of which classes were incorrectly predicted
    incorrect = {}
    for label in labels:
        incorrect[label] = 0

    # Iterate through the results for each image in the subset
    for i in range(len(result)):
        # Automatically increase count of label in dictionary for appearing
        all_labels[result[i][1]] += 1

        # If the actual id/label aligns with the predicted one, add to correct count
        if dataset2[i]["label"] == result[i][3]:
            correct += 1
            total += 1
            if total % 50 == 0:
              print(f"Model accurately predicted {result[i][1]} with {result[i][2] * 100}% confidence.")
        else:
            # If they do not align, increase count of predicted id/label in incorrect dictionary
            total += 1
            if total % 50 == 0:
              print(f"Model inaccurately predicted {result[i][1]} with {result[i][2] * 100}% confidence.")
            incorrect[result[i][1]] += 1

    print(f"Accuracy: {(correct/total) * 100}%")

    worst_accuracy = []
    # For every label, calculate percentage predicted correctly by subtracting total by incorrect
    for label in all_labels:
        correct =  all_labels[label] - incorrect[label]
        total = all_labels[label]
        if total != 0:
          print(f"For {label}: Predicted {correct} out of {total} correct. {(correct) / total * 100}% Accuracy")
          worst_accuracy.append([label, correct/total])
        else:
          print(f"{label} was not in this analysis set")

    worst_group = min(worst_accuracy, key=lambda x: x[1])
    print(f"The worst performing group is '{worst_group[0]}' with an accuracy of {worst_group[1] * 100}%")


def data_analysis(predictions, data_type = "test"):
    cleaned = prediction_reformat(predictions)
    final_results = accuracy(cleaned, data_type)

    return final_results


def train_shuffled(num_img, batch_size=10, num_epoch=2):
    # Set up training parameters
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    optimizer = optim.Adam(model.parameters(), lr=1e-5)
    model.to(device)
    model.train()
    best_loss = float("inf")
    total_loss = 0

    for epoch in range(num_epoch):
        # Shuffle the dataset at the beginning of each epoch
        random.shuffle(dataset2)
        epoch_loss = 0
        t0 = time.perf_counter()

        # Process the dataset in batches
        for i in range(num_img // batch_size):
            start = i * batch_size
            end = (i + 1) * batch_size

            # Define the batch
            batch = dataset2[start:end]
            images = [item["image"] for item in batch]
            label = [item["label"] for item in batch]

            # Convert images and labels to tensors and move them to device
            inputs = processor(text=labels, images=images, return_tensors="pt", padding=False).to(device)


            # Model forward pass
            output = model(**inputs)
            logits_per_image = output.logits_per_image
            logits_per_text = output.logits_per_text.squeeze()

            # Convert labels to tensor for calculating loss
            targets = torch.tensor(label).to(device)

            # Calculate loss
            loss_img = F.cross_entropy(logits_per_image, targets)
            loss_text = F.cross_entropy(logits_per_text, targets)
            loss = (loss_img + loss_text) / 2

            # Backpropagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track loss and time
            epoch_loss += loss.item()
            print(f"Finished batch {i + 1}/{num_img // batch_size} with loss {loss.item():.4f}")

        # Epoch completion tracking
        avg_loss = epoch_loss / (num_img // batch_size)
        total_loss += epoch_loss
        t1 = time.perf_counter()

        # Save model if the current epoch's loss is the best so far
        if epoch_loss < best_loss:
            best_loss = epoch_loss
            torch.save(model.state_dict(), '/content/clip.pt')

        print(f"Epoch {epoch+1}/{num_epoch} completed in {t1 - t0:.2f} seconds, Loss: {avg_loss:.4f}")

    return total_loss / (num_epoch * (num_img // batch_size))
# Out:
# Loaded full_numpy_bitmap_crab.npy with shape: (126930, 784)
# Successfully processed full_numpy_bitmap_crab.npy in 5.18 seconds
# Loaded full_numpy_bitmap_crocodile.npy with shape: (127932, 784)
# Successfully processed full_numpy_bitmap_crocodile.npy in 3.54 seconds
# Loaded full_numpy_bitmap_lion.npy with shape: (120949, 784)
# Successfully processed full_numpy_bitmap_lion.npy in 2.89 seconds
# Loaded full_numpy_bitmap_lobster.npy with shape: (140175, 784)
# Successfully processed full_numpy_bitmap_lobster.npy in 3.40 seconds
# Loaded full_numpy_bitmap_monkey.npy with shape: (127633, 784)
# Successfully processed full_numpy_bitmap_monkey.npy in 4.17 seconds
# Loaded full_numpy_bitmap_octopus.npy with shape: (150152, 784)
# Successfully processed full_numpy_bitmap_octopus.npy in 4.52 seconds
# Loaded full_numpy_bitmap_panda.npy with shape: (113613, 784)
# Successfully processed full_numpy_bitmap_panda.npy in 2.72 seconds
# Loaded full_numpy_bitmap_swan.npy with shape: (152088, 784)
# Successfully processed full_numpy_bitmap_swan.npy in 5.45 seconds
# {'a drawing of a crab': 0, 'a drawing of a crocodile': 1, 'a drawing of a lion': 2, 'a drawing of a lobster': 3, 'a drawing of a monkey': 4, 'a drawing of a octopus': 5, 'a drawing of a panda': 6, 'a drawing of a swan': 7}

# %%
random.shuffle(dataset2)

# %%
model = CLIPModel.from_pretrained("openai/clip-vit-large-patch14")
pretrain = homemade_batch(5000)
pretrain_result = data_analysis(pretrain)

#I already finetuned on 5000 shuffled images for 5 epochs

model.load_state_dict(torch.load('/content/clip.pt', weights_only=True))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

train = homemade_batch(5000)
train_result = data_analysis(train)
# Out:
# Finished batch 1 of 500 in 0.6293340129998342 seconds
# Finished batch 51 of 500 in 0.7488800119999723 seconds
# Finished batch 101 of 500 in 0.707566960999884 seconds
# Finished batch 151 of 500 in 0.7184446290000324 seconds
# Finished batch 201 of 500 in 0.727902560000075 seconds
# Finished batch 251 of 500 in 0.7142901390000134 seconds
# Finished batch 301 of 500 in 0.7096442060001209 seconds
# Finished batch 351 of 500 in 0.7081775970000308 seconds
# Finished batch 401 of 500 in 0.7164290860000619 seconds
# Finished batch 451 of 500 in 0.7139693310000439 seconds
# Finished entire dataset in 357.89235330199995 seconds
# Model inaccurately predicted a drawing of a crab with 51.59479379653931% confidence.
# Model accurately predicted a drawing of a lobster with 56.13514184951782% confidence.
# Model accurately predicted a drawing of a panda with 29.587602615356445% confidence.
# Model inaccurately predicted a drawing of a lobster with 26.39046311378479% confidence.
# Model inaccurately predicted a drawing of a octopus with 31.87692165374756% confidence.
# Model accurately predicted a drawing of a crocodile with 85.93136668205261% confidence.
# Model inaccurately predicted a drawing of a monkey with 44.39957141876221% confidence.
# Model inaccurately predicted a drawing of a swan with 32.23205506801605% confidence.
# Model accurately predicted a drawing of a lion with 38.8107031583786% confidence.
# Model accurately predicted a drawing of a crocodile with 30.07943034172058% confidence.
# Model accurately predicted a drawing of a crocodile with 41.96845591068268% confidence.
# Model accurately predicted a drawing of a monkey with 81.1073362827301% confidence.
# Model inaccurately predicted a drawing of a crab with 58.48115086555481% confidence.
# Model accurately predicted a drawing of a panda with 40.834417939186096% confidence.
# Model inaccurately predicted a drawing of a panda with 28.280729055404663% confidence.
# Model inaccurately predicted a drawing of a crocodile with 32.077011466026306% confidence.
# Model inaccurately predicted a drawing of a crocodile with 28.31234037876129% confidence.
# Model accurately predicted a drawing of a crab with 62.332308292388916% confidence.
# Model inaccurately predicted a drawing of a crab with 30.177244544029236% confidence.
# Model accurately predicted a drawing of a panda with 34.40907895565033% confidence.
# Model accurately predicted a drawing of a panda with 90.20639061927795% confidence.
# Model inaccurately predicted a drawing of a octopus with 24.326656758785248% confidence.
# Model accurately predicted a drawing of a monkey with 35.05088686943054% confidence.
# Model inaccurately predicted a drawing of a panda with 54.915428161621094% confidence.
# Model inaccurately predicted a drawing of a monkey with 56.23195171356201% confidence.
# Model accurately predicted a drawing of a lion with 55.71103096008301% confidence.
# Model accurately predicted a drawing of a octopus with 48.614174127578735% confidence.
# Model inaccurately predicted a drawing of a octopus with 51.20174288749695% confidence.
# Model inaccurately predicted a drawing of a swan with 19.75994110107422% confidence.
# Model accurately predicted a drawing of a crocodile with 65.17099142074585% confidence.
# Model accurately predicted a drawing of a lobster with 45.9035724401474% confidence.
# Model inaccurately predicted a drawing of a octopus with 33.236074447631836% confidence.
# Model inaccurately predicted a drawing of a lobster with 46.489158272743225% confidence.
# Model inaccurately predicted a drawing of a swan with 44.08639371395111% confidence.
# Model inaccurately predicted a drawing of a crocodile with 37.836042046546936% confidence.
# Model inaccurately predicted a drawing of a crab with 31.340548396110535% confidence.
# Model accurately predicted a drawing of a lobster with 26.13723576068878% confidence.
# Model accurately predicted a drawing of a crocodile with 26.357346773147583% confidence.
# Model inaccurately predicted a drawing of a crocodile with 40.53831100463867% confidence.
# Model inaccurately predicted a drawing of a panda with 51.31765007972717% confidence.
# Model accurately predicted a drawing of a octopus with 98.6659049987793% confidence.
# Model inaccurately predicted a drawing of a swan with 38.93294632434845% confidence.
# Model inaccurately predicted a drawing of a octopus with 53.34433317184448% confidence.
# Model inaccurately predicted a drawing of a octopus with 65.5942440032959% confidence.
# Model accurately predicted a drawing of a crocodile with 62.39480376243591% confidence.
# Model accurately predicted a drawing of a octopus with 98.62791299819946% confidence.
# Model accurately predicted a drawing of a crocodile with 49.17534589767456% confidence.
# Model accurately predicted a drawing of a monkey with 94.66087222099304% confidence.
# Model accurately predicted a drawing of a octopus with 88.63419890403748% confidence.
# Model accurately predicted a drawing of a crab with 55.30824661254883% confidence.
# Model accurately predicted a drawing of a crocodile with 26.74197256565094% confidence.
# Model inaccurately predicted a drawing of a lobster with 26.19871497154236% confidence.
# Model inaccurately predicted a drawing of a crab with 65.15078544616699% confidence.
# Model inaccurately predicted a drawing of a swan with 44.07253563404083% confidence.
# Model accurately predicted a drawing of a crocodile with 76.91430449485779% confidence.
# Model accurately predicted a drawing of a swan with 96.31826281547546% confidence.
# Model inaccurately predicted a drawing of a octopus with 24.376995861530304% confidence.
# Model accurately predicted a drawing of a panda with 48.95586371421814% confidence.
# Model accurately predicted a drawing of a crocodile with 99.75903034210205% confidence.
# Model accurately predicted a drawing of a crocodile with 30.11300563812256% confidence.
# Model inaccurately predicted a drawing of a lobster with 19.347265362739563% confidence.
# Model accurately predicted a drawing of a monkey with 99.42952990531921% confidence.
# Model inaccurately predicted a drawing of a monkey with 33.12925100326538% confidence.
# Model accurately predicted a drawing of a swan with 72.4965512752533% confidence.
# Model inaccurately predicted a drawing of a panda with 63.92867565155029% confidence.
# Model accurately predicted a drawing of a octopus with 93.76315474510193% confidence.
# Model accurately predicted a drawing of a swan with 98.91865849494934% confidence.
# Model inaccurately predicted a drawing of a panda with 73.04159998893738% confidence.
# Model accurately predicted a drawing of a crocodile with 35.359564423561096% confidence.
# Model accurately predicted a drawing of a monkey with 99.38697814941406% confidence.
# Model inaccurately predicted a drawing of a lobster with 35.49030423164368% confidence.
# Model accurately predicted a drawing of a lobster with 26.691949367523193% confidence.
# Model accurately predicted a drawing of a swan with 99.89398121833801% confidence.
# Model inaccurately predicted a drawing of a crab with 30.988234281539917% confidence.
# Model accurately predicted a drawing of a crab with 94.504714012146% confidence.
# Model accurately predicted a drawing of a swan with 63.94416689872742% confidence.
# Model accurately predicted a drawing of a swan with 98.67298603057861% confidence.
# Model inaccurately predicted a drawing of a monkey with 43.72026026248932% confidence.
# Model inaccurately predicted a drawing of a crab with 56.16536736488342% confidence.
# Model inaccurately predicted a drawing of a crocodile with 45.06750702857971% confidence.
# Model accurately predicted a drawing of a crocodile with 23.25163036584854% confidence.
# Model inaccurately predicted a drawing of a crab with 21.24800831079483% confidence.
# Model inaccurately predicted a drawing of a octopus with 34.85484421253204% confidence.
# Model inaccurately predicted a drawing of a panda with 23.92195016145706% confidence.
# Model inaccurately predicted a drawing of a octopus with 47.61946499347687% confidence.
# Model accurately predicted a drawing of a crocodile with 27.872690558433533% confidence.
# Model inaccurately predicted a drawing of a swan with 62.48409152030945% confidence.
# Model inaccurately predicted a drawing of a octopus with 18.32694709300995% confidence.
# Model inaccurately predicted a drawing of a monkey with 22.01043963432312% confidence.
# Model inaccurately predicted a drawing of a lobster with 34.497153759002686% confidence.
# Model accurately predicted a drawing of a monkey with 96.28010392189026% confidence.
# Model accurately predicted a drawing of a octopus with 58.82876515388489% confidence.
# Model inaccurately predicted a drawing of a monkey with 24.042481184005737% confidence.
# Model accurately predicted a drawing of a crab with 99.59856867790222% confidence.
# Model accurately predicted a drawing of a swan with 77.41828560829163% confidence.
# Model accurately predicted a drawing of a monkey with 63.60459923744202% confidence.
# Model accurately predicted a drawing of a swan with 99.76434111595154% confidence.
# Model accurately predicted a drawing of a panda with 76.83107852935791% confidence.
# Model accurately predicted a drawing of a octopus with 81.29924535751343% confidence.
# Model inaccurately predicted a drawing of a octopus with 59.34274196624756% confidence.
# Accuracy: 56.10000000000001%
# For a drawing of a crab: Predicted 345 out of 794 correct. 43.45088161209068% Accuracy
# For a drawing of a crocodile: Predicted 423 out of 764 correct. 55.366492146596855% Accuracy
# For a drawing of a lion: Predicted 94 out of 158 correct. 59.49367088607595% Accuracy
# For a drawing of a lobster: Predicted 202 out of 435 correct. 46.43678160919541% Accuracy
# For a drawing of a monkey: Predicted 316 out of 566 correct. 55.830388692579504% Accuracy
# For a drawing of a octopus: Predicted 545 out of 1063 correct. 51.269990592662275% Accuracy
# For a drawing of a panda: Predicted 373 out of 560 correct. 66.60714285714285% Accuracy
# For a drawing of a swan: Predicted 507 out of 660 correct. 76.81818181818181% Accuracy
# The worst performing group is 'a drawing of a crab' with an accuracy of 43.45088161209068%
# Finished batch 1 of 500 in 0.6292722839998532 seconds
# Finished batch 51 of 500 in 0.7372898449998502 seconds
# Finished batch 101 of 500 in 0.7370045110001229 seconds
# Finished batch 151 of 500 in 0.7541543920001459 seconds
# Finished batch 201 of 500 in 0.7602183019998847 seconds
# Finished batch 251 of 500 in 0.728917600999921 seconds
# Finished batch 301 of 500 in 0.7332705959997838 seconds
# Finished batch 351 of 500 in 0.7293978669999888 seconds
# Finished batch 401 of 500 in 0.7323522480000975 seconds
# Finished batch 451 of 500 in 0.733478512000147 seconds
# Finished entire dataset in 368.2490360669999 seconds
# Model accurately predicted a drawing of a monkey with 53.71118187904358% confidence.
# Model accurately predicted a drawing of a lobster with 63.52211236953735% confidence.
# Model accurately predicted a drawing of a panda with 72.81255722045898% confidence.
# Model accurately predicted a drawing of a swan with 64.79592323303223% confidence.
# Model inaccurately predicted a drawing of a crab with 38.323190808296204% confidence.
# Model accurately predicted a drawing of a crocodile with 39.60973620414734% confidence.
# Model inaccurately predicted a drawing of a monkey with 29.425236582756042% confidence.
# Model accurately predicted a drawing of a crab with 59.712040424346924% confidence.
# Model accurately predicted a drawing of a lion with 47.55213260650635% confidence.
# Model accurately predicted a drawing of a crocodile with 72.72182106971741% confidence.
# Model accurately predicted a drawing of a crocodile with 64.53190445899963% confidence.
# Model accurately predicted a drawing of a monkey with 66.46960973739624% confidence.
# Model accurately predicted a drawing of a lobster with 56.120365858078% confidence.
# Model accurately predicted a drawing of a panda with 81.86151385307312% confidence.
# Model accurately predicted a drawing of a monkey with 56.64820075035095% confidence.
# Model inaccurately predicted a drawing of a swan with 31.670382618904114% confidence.
# Model inaccurately predicted a drawing of a crocodile with 56.64395093917847% confidence.
# Model accurately predicted a drawing of a crab with 61.48708462715149% confidence.
# Model accurately predicted a drawing of a octopus with 50.543469190597534% confidence.
# Model accurately predicted a drawing of a panda with 38.53166103363037% confidence.
# Model accurately predicted a drawing of a panda with 76.42504572868347% confidence.
# Model accurately predicted a drawing of a lion with 44.66899335384369% confidence.
# Model accurately predicted a drawing of a monkey with 49.10503923892975% confidence.
# Model inaccurately predicted a drawing of a panda with 56.866443157196045% confidence.
# Model inaccurately predicted a drawing of a monkey with 40.48326909542084% confidence.
# Model accurately predicted a drawing of a lion with 40.85972607135773% confidence.
# Model accurately predicted a drawing of a octopus with 66.26996397972107% confidence.
# Model accurately predicted a drawing of a lion with 40.39067327976227% confidence.
# Model accurately predicted a drawing of a crocodile with 70.0860857963562% confidence.
# Model accurately predicted a drawing of a crocodile with 72.70609140396118% confidence.
# Model accurately predicted a drawing of a lobster with 55.67384362220764% confidence.
# Model accurately predicted a drawing of a lion with 48.80131185054779% confidence.
# Model accurately predicted a drawing of a crab with 56.78829550743103% confidence.
# Model accurately predicted a drawing of a crab with 35.020819306373596% confidence.
# Model inaccurately predicted a drawing of a lobster with 45.5459862947464% confidence.
# Model accurately predicted a drawing of a lobster with 47.88477420806885% confidence.
# Model accurately predicted a drawing of a lobster with 45.27805745601654% confidence.
# Model accurately predicted a drawing of a crocodile with 61.28571033477783% confidence.
# Model accurately predicted a drawing of a crab with 57.51610994338989% confidence.
# Model accurately predicted a drawing of a monkey with 61.10987663269043% confidence.
# Model accurately predicted a drawing of a octopus with 67.60407090187073% confidence.
# Model accurately predicted a drawing of a crocodile with 70.06344795227051% confidence.
# Model accurately predicted a drawing of a swan with 71.16448879241943% confidence.
# Model accurately predicted a drawing of a swan with 70.12050151824951% confidence.
# Model accurately predicted a drawing of a crocodile with 74.01579022407532% confidence.
# Model accurately predicted a drawing of a octopus with 67.13764667510986% confidence.
# Model accurately predicted a drawing of a crocodile with 69.71377730369568% confidence.
# Model accurately predicted a drawing of a monkey with 65.17130732536316% confidence.
# Model accurately predicted a drawing of a octopus with 56.5190851688385% confidence.
# Model accurately predicted a drawing of a crab with 55.72764873504639% confidence.
# Model accurately predicted a drawing of a crocodile with 60.29701232910156% confidence.
# Model accurately predicted a drawing of a lion with 19.348494708538055% confidence.
# Model accurately predicted a drawing of a lobster with 46.62456512451172% confidence.
# Model accurately predicted a drawing of a crab with 59.46438908576965% confidence.
# Model accurately predicted a drawing of a crocodile with 69.33466792106628% confidence.
# Model accurately predicted a drawing of a swan with 73.13691973686218% confidence.
# Model accurately predicted a drawing of a lion with 47.261157631874084% confidence.
# Model accurately predicted a drawing of a panda with 77.63363718986511% confidence.
# Model accurately predicted a drawing of a crocodile with 73.99222254753113% confidence.
# Model accurately predicted a drawing of a crocodile with 62.982797622680664% confidence.
# Model accurately predicted a drawing of a crocodile with 51.510089635849% confidence.
# Model accurately predicted a drawing of a monkey with 60.673654079437256% confidence.
# Model inaccurately predicted a drawing of a monkey with 52.06313729286194% confidence.
# Model accurately predicted a drawing of a swan with 74.67418909072876% confidence.
# Model accurately predicted a drawing of a monkey with 60.26207208633423% confidence.
# Model accurately predicted a drawing of a octopus with 67.67913103103638% confidence.
# Model accurately predicted a drawing of a swan with 71.33254408836365% confidence.
# Model accurately predicted a drawing of a lion with 38.24591338634491% confidence.
# Model accurately predicted a drawing of a crocodile with 67.92842149734497% confidence.
# Model accurately predicted a drawing of a monkey with 60.36695837974548% confidence.
# Model accurately predicted a drawing of a crocodile with 70.95128297805786% confidence.
# Model accurately predicted a drawing of a lobster with 55.52547574043274% confidence.
# Model accurately predicted a drawing of a swan with 72.05823063850403% confidence.
# Model accurately predicted a drawing of a lion with 39.45119082927704% confidence.
# Model accurately predicted a drawing of a crab with 58.789968490600586% confidence.
# Model accurately predicted a drawing of a swan with 73.40641021728516% confidence.
# Model accurately predicted a drawing of a swan with 70.6136167049408% confidence.
# Model accurately predicted a drawing of a panda with 77.09962725639343% confidence.
# Model accurately predicted a drawing of a octopus with 32.82681107521057% confidence.
# Model inaccurately predicted a drawing of a swan with 39.91783261299133% confidence.
# Model accurately predicted a drawing of a crocodile with 71.84081673622131% confidence.
# Model accurately predicted a drawing of a crocodile with 71.05281949043274% confidence.
# Model accurately predicted a drawing of a monkey with 57.82784819602966% confidence.
# Model accurately predicted a drawing of a crab with 55.14360070228577% confidence.
# Model accurately predicted a drawing of a lion with 21.874932944774628% confidence.
# Model accurately predicted a drawing of a crocodile with 68.94675493240356% confidence.
# Model accurately predicted a drawing of a crab with 54.805028438568115% confidence.
# Model accurately predicted a drawing of a crab with 58.27444791793823% confidence.
# Model accurately predicted a drawing of a panda with 63.02023530006409% confidence.
# Model accurately predicted a drawing of a crocodile with 63.002097606658936% confidence.
# Model accurately predicted a drawing of a monkey with 62.92136311531067% confidence.
# Model accurately predicted a drawing of a octopus with 52.5068998336792% confidence.
# Model accurately predicted a drawing of a panda with 72.09954261779785% confidence.
# Model accurately predicted a drawing of a crab with 47.2516804933548% confidence.
# Model accurately predicted a drawing of a swan with 73.45197796821594% confidence.
# Model accurately predicted a drawing of a monkey with 60.77659726142883% confidence.
# Model accurately predicted a drawing of a swan with 69.6125864982605% confidence.
# Model accurately predicted a drawing of a panda with 79.76154088973999% confidence.
# Model accurately predicted a drawing of a octopus with 66.16539359092712% confidence.
# Model inaccurately predicted a drawing of a monkey with 24.841633439064026% confidence.
# Accuracy: 87.86%
# For a drawing of a crab: Predicted 521 out of 636 correct. 81.91823899371069% Accuracy
# For a drawing of a crocodile: Predicted 525 out of 623 correct. 84.26966292134831% Accuracy
# For a drawing of a lion: Predicted 462 out of 463 correct. 99.78401727861771% Accuracy
# For a drawing of a lobster: Predicted 488 out of 621 correct. 78.58293075684381% Accuracy
# For a drawing of a monkey: Predicted 508 out of 603 correct. 84.24543946932008% Accuracy
# For a drawing of a octopus: Predicted 688 out of 707 correct. 97.31258840169731% Accuracy
# For a drawing of a panda: Predicted 507 out of 613 correct. 82.70799347471451% Accuracy
# For a drawing of a swan: Predicted 694 out of 734 correct. 94.55040871934605% Accuracy
# The worst performing group is 'a drawing of a lobster' with an accuracy of 78.58293075684381%
